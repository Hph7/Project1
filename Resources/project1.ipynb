# %%
# Dependencies
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt

# import csv data files
education_file = "Resources/education.csv"
childmarriage_file = "Resources/childmarriage.csv"


# create dataframes for each
education_file_df = pd.read_csv(education_file, encoding="ISO-8859-1")
childmarriage_file_df = pd.read_csv(childmarriage_file, encoding="ISO-8859-1")
countries_df = pd.read_html('https://developers.google.com/public-data/docs/canonical/countries_csv')

#education_file_df.head()
#childmarriage_file_df.head()
#countries_df[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8f0802f51bee> in <module>
#      11
#      12 # create dataframes for each
# ---> 13 education_file_df = pd.read_csv(education_file, encoding="ISO-8859-1")
#      14 childmarriage_file_df = pd.read_csv(childmarriage_file, encoding="ISO-8859-1")
#      15 countries_df = pd.read_html('https://developers.google.com/public-data/docs/canonical/countries_csv')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Resources/education.csv' does not exist: b'Resources/education.csv'

# %%
filtered_education = education_file_df.filter(["Indicator"== "Youth literacy rate, population 15-24 years, both sexes (%)",
                                              "LOCATION", "Country","TIME", "Value"])
filtered_education.head()

# %%
childmarriage_file_df.head()
# Out:
#                   Dataflow Geographic Area  \
# 0  Cross-sector Indicators        Botswana
# 1  Cross-sector Indicators      Uzbekistan
# 2  Cross-sector Indicators     Philippines
# 3  Cross-sector Indicators    South Africa
# 4  Cross-sector Indicators    South Africa
#
#                                            Indicator     Sex  Time Period  \
# 0  Percentage of women (aged 20-24 years) married...  Female         1988
# 1  Percentage of men (aged 20-24 years) married o...    Male         2002
# 2  Percentage of men (aged 20-24 years) married o...    Male         2003
# 3  Percentage of women (aged 20-24 years) married...  Female         2003
# 4  Percentage of women (aged 20-24 years) married...  Female         2003
#
#    Observation Value  Unit Multiplier Unit of Measure Observation Status  \
# 0               10.0              NaN               %           Reported
# 1                0.5              NaN               %           Reported
# 2                2.9              NaN               %           Reported
# 3                0.8              NaN               %           Reported
# 4                5.6              NaN               %           Reported
#
#   Observation Confidentaility  ...  Weighted Sample Size  \
# 0                        Free  ...                   NaN
# 1                        Free  ...                   NaN
# 2                        Free  ...                   NaN
# 3                        Free  ...                   NaN
# 4                        Free  ...                   NaN
#
#    Observation Footnote  Series Footnote Data Source  \
# 0                   NaN              NaN    DHS 1988
# 1                   NaN              NaN    DHS 2002
# 2                   NaN              NaN    DHS 2003
# 3                   NaN              NaN    DHS 2016
# 4                   NaN              NaN    DHS 2003
#
#    Citation of or link to the data source Custodian  \
# 0                                     NaN       NaN
# 1                                     NaN       NaN
# 2                                     NaN       NaN
# 3                                     NaN       NaN
# 4                                     NaN       NaN
#
#    Time period activity related to when the data are collected  \
# 0                                   End of fieldwork
# 1                                   End of fieldwork
# 2                                   End of fieldwork
# 3                                   End of fieldwork
# 4                                   End of fieldwork
#
#    Reference Period The period of time for which data are provided  \
# 0               NaN                                           1988
# 1               NaN                                           2002
# 2               NaN                                           2003
# 3               NaN                                           2003
# 4               NaN                                           2003
#
#           Current Age
# 0  20 to 24 years old
# 1  20 to 24 years old
# 2  20 to 24 years old
# 3  20 to 24 years old
# 4  20 to 24 years old
#
# [5 rows x 22 columns]

# %%
countries_df[0]
# Out:
#     country   latitude  longitude                  name
# 0        AD  42.546245   1.601554               Andorra
# 1        AE  23.424076  53.847818  United Arab Emirates
# 2        AF  33.939110  67.709953           Afghanistan
# 3        AG  17.060816 -61.796428   Antigua and Barbuda
# 4        AI  18.220554 -63.068615              Anguilla
# ..      ...        ...        ...                   ...
# 240      YE  15.552727  48.516388                 Yemen
# 241      YT -12.827500  45.166244               Mayotte
# 242      ZA -30.559482  22.937506          South Africa
# 243      ZM -13.133897  27.849332                Zambia
# 244      ZW -19.015438  29.154857              Zimbabwe
#
# [245 rows x 4 columns]

# %%
merged_edu_child_mar = pd.merge(left=survey_sub, right=species_sub, how='left', left_on='species_id', right_on='species_id')
merged_edu_child_mar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-25babc82580a> in <module>
# ----> 1 merged_edu_child_mar = pd.merge(left=survey_sub, right=species_sub, how='left', left_on='species_id', right_on='species_id')
#       2 merged_edu_child_mar
#
# NameError: name 'pd' is not defined
